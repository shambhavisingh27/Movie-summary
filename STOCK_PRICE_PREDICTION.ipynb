# %% [markdown]
# <a href="https://colab.research.google.com/github/shambhavisingh27/Movie-summary/blob/main/STOCK_PRICE_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING LIBRARIES AND DATA

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('/GOOG.csv') #data set
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']]
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0]))
df.set_index('date',drop=True,inplace=True)
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7)) #opening and closing price plot on date index
ax[0].plot(df['open'],label='Open',color='pink')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='purple')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# DATA PREPROCESSING

# %% [markdown]
# D

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# CREATING LSTM MODEL

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30,902
# Trainable params: 30,902
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 10s 170ms/step - loss: 0.0079 - mean_absolute_error: 0.0630 - val_loss: 0.0140 - val_mean_absolute_error: 0.0980
# Epoch 2/100
# 28/28 [==============================] - 2s 88ms/step - loss: 7.4658e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0045 - val_mean_absolute_error: 0.0523
# Epoch 3/100
# 28/28 [==============================] - 2s 72ms/step - loss: 4.4157e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0019 - val_mean_absolute_error: 0.0335
# Epoch 4/100
# 28/28 [==============================] - 2s 63ms/step - loss: 4.2746e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0026 - val_mean_absolute_error: 0.0386
# Epoch 5/100
# 28/28 [==============================] - 2s 67ms/step - loss: 4.1261e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 6/100
# 28/28 [==============================] - 2s 67ms/step - loss: 3.9681e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0039 - val_mean_absolute_error: 0.0495
# Epoch 7/100
# 28/28 [==============================] - 3s 91ms/step - loss: 3.8377e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0036 - val_mean_absolute_error: 0.0473
# Epoch 8/100
# 28/28 [==============================] - 2s 87ms/step - loss: 3.9053e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0023 - val_mean_absolute_error: 0.0360
# Epoch 9/100
# 28/28 [==============================] - 2s 67ms/step - loss: 3.8435e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0029 - val_mean_absolute_error: 0.0417
# Epoch 10/100
# 28/28 [==============================] - 2s 74ms/step - loss: 3.5844e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0032 - val_mean_absolute_error: 0.0440
# Epoch 11/100
# 28/28 [==============================] - 2s 70ms/step - loss: 3.6594e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0030 - val_mean_absolute_error: 0.0420
# Epoch 12/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.5561e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0020 - val_mean_absolute_error: 0.0340
# Epoch 13/100
# 28/28 [==============================] - 2s 79ms/step - loss: 3.4169e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0040 - val_mean_absolute_error: 0.0516
# Epoch 14/100
# 28/28 [==============================] - 3s 95ms/step - loss: 3.1959e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0032 - val_mean_absolute_error: 0.0444
# Epoch 15/100
# 28/28 [==============================] - 2s 71ms/step - loss: 3.3216e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0019 - val_mean_absolute_error: 0.0325
# Epoch 16/100
# 28/28 [==============================] - 2s 65ms/step - loss: 3.1294e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0021 - val_mean_absolute_error: 0.0344
# Epoch 17/100
# 28/28 [==============================] - 2s 63ms/step - loss: 3.3536e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0033 - val_mean_absolute_error: 0.0458
# Epoch 18/100
# 28/28 [==============================] - 3s 91ms/step - loss: 3.0086e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0037 - val_mean_absolute_error: 0.0490
# Epoch 19/100
# 28/28 [==============================] - 2s 82ms/step - loss: 3.1726e-04 - mean_absolute_error: 0.0129 - val_loss: 0.0030 - val_mean_absolute_error: 0.0438
# Epoch 20/100
# 28/28 [==============================] - 3s 94ms/step - loss: 2.9039e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0031 - val_mean_absolute_error: 0.0439
# Epoch 21/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.8092e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0028 - val_mean_absolute_error: 0.0417
# Epoch 22/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.8540e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0025 - val_mean_absolute_error: 0.0383
# Epoch 23/100
# 28/28 [==============================] - 2s 70ms/step - loss: 3.0022e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0043 - val_mean_absolute_error: 0.0536
# Epoch 24/100
# 28/28 [==============================] - 2s 70ms/step - loss: 2.8548e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0050 - val_mean_absolute_error: 0.0578
# Epoch 25/100
# 28/28 [==============================] - 2s 69ms/step - loss: 3.0207e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0036 - val_mean_absolute_error: 0.0477
# Epoch 26/100
# 28/28 [==============================] - 3s 103ms/step - loss: 2.7753e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0038 - val_mean_absolute_error: 0.0493
# Epoch 27/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.5505e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0025 - val_mean_absolute_error: 0.0385
# Epoch 28/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.6404e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0046 - val_mean_absolute_error: 0.0559
# Epoch 29/100
# 28/28 [==============================] - 2s 75ms/step - loss: 2.9209e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0014 - val_mean_absolute_error: 0.0269
# Epoch 30/100
# 28/28 [==============================] - 2s 70ms/step - loss: 3.3732e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0052 - val_mean_absolute_error: 0.0609
# Epoch 31/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.7060e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0022 - val_mean_absolute_error: 0.0353
# Epoch 32/100
# 28/28 [==============================] - 3s 117ms/step - loss: 2.4477e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0021 - val_mean_absolute_error: 0.0348
# Epoch 33/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.4907e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 34/100
# 28/28 [==============================] - 2s 73ms/step - loss: 2.4674e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0018 - val_mean_absolute_error: 0.0323
# Epoch 35/100
# 28/28 [==============================] - 2s 65ms/step - loss: 2.4347e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0022 - val_mean_absolute_error: 0.0357
# Epoch 36/100
# 28/28 [==============================] - 2s 67ms/step - loss: 2.5128e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 37/100
# 28/28 [==============================] - 2s 67ms/step - loss: 2.3857e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0028 - val_mean_absolute_error: 0.0414
# Epoch 38/100
# 28/28 [==============================] - 3s 107ms/step - loss: 2.2321e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0026 - val_mean_absolute_error: 0.0399
# Epoch 39/100
# 28/28 [==============================] - 2s 74ms/step - loss: 2.2176e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0023 - val_mean_absolute_error: 0.0363
# Epoch 40/100
# 28/28 [==============================] - 2s 73ms/step - loss: 2.2054e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0020 - val_mean_absolute_error: 0.0329
# Epoch 41/100
# 28/28 [==============================] - 2s 74ms/step - loss: 2.1505e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0027 - val_mean_absolute_error: 0.0396
# Epoch 42/100
# 28/28 [==============================] - 2s 67ms/step - loss: 2.5368e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0018 - val_mean_absolute_error: 0.0311
# Epoch 43/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.1452e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0023 - val_mean_absolute_error: 0.0367
# Epoch 44/100
# 28/28 [==============================] - 3s 101ms/step - loss: 2.1552e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0027 - val_mean_absolute_error: 0.0414
# Epoch 45/100
# 28/28 [==============================] - 2s 76ms/step - loss: 2.2683e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0022 - val_mean_absolute_error: 0.0358
# Epoch 46/100
# 28/28 [==============================] - 2s 67ms/step - loss: 2.1975e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0021 - val_mean_absolute_error: 0.0343
# Epoch 47/100
# 28/28 [==============================] - 2s 69ms/step - loss: 2.2062e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0027 - val_mean_absolute_error: 0.0407
# Epoch 48/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.1571e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0021 - val_mean_absolute_error: 0.0357
# Epoch 49/100
# 28/28 [==============================] - 2s 71ms/step - loss: 2.0671e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0044 - val_mean_absolute_error: 0.0549
# Epoch 50/100
# 28/28 [==============================] - 5s 173ms/step - loss: 2.0486e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0019 - val_mean_absolute_error: 0.0325
# Epoch 51/100
# 28/28 [==============================] - 2s 67ms/step - loss: 2.1064e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0011 - val_mean_absolute_error: 0.0235
# Epoch 52/100
# 28/28 [==============================] - 2s 66ms/step - loss: 2.2087e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0020 - val_mean_absolute_error: 0.0341
# Epoch 53/100
# 28/28 [==============================] - 2s 71ms/step - loss: 2.0544e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0023 - val_mean_absolute_error: 0.0384
# Epoch 54/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.0727e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0026 - val_mean_absolute_error: 0.0411
# Epoch 55/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.8012e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0015 - val_mean_absolute_error: 0.0284
# Epoch 56/100
# 28/28 [==============================] - 3s 110ms/step - loss: 1.7969e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 57/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.7912e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 58/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.8139e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0013 - val_mean_absolute_error: 0.0259
# Epoch 59/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.9915e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0017 - val_mean_absolute_error: 0.0305
# Epoch 60/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.9184e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 61/100
# 28/28 [==============================] - 2s 71ms/step - loss: 2.1225e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0020 - val_mean_absolute_error: 0.0342
# Epoch 62/100
# 28/28 [==============================] - 3s 113ms/step - loss: 1.8783e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0017 - val_mean_absolute_error: 0.0319
# Epoch 63/100
# 28/28 [==============================] - 2s 64ms/step - loss: 1.6443e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0026 - val_mean_absolute_error: 0.0417
# Epoch 64/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.7778e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 65/100
# 28/28 [==============================] - 2s 62ms/step - loss: 1.8916e-04 - mean_absolute_error: 0.0101 - val_loss: 6.3858e-04 - val_mean_absolute_error: 0.0188
# Epoch 66/100
# 28/28 [==============================] - 2s 72ms/step - loss: 2.0220e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0025 - val_mean_absolute_error: 0.0411
# Epoch 67/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.6941e-04 - mean_absolute_error: 0.0095 - val_loss: 9.2030e-04 - val_mean_absolute_error: 0.0218
# Epoch 68/100
# 28/28 [==============================] - 3s 106ms/step - loss: 1.6780e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355
# Epoch 69/100
# 28/28 [==============================] - 2s 80ms/step - loss: 1.8120e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0016 - val_mean_absolute_error: 0.0297
# Epoch 70/100
# 28/28 [==============================] - 2s 72ms/step - loss: 1.7177e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0017 - val_mean_absolute_error: 0.0321
# Epoch 71/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.8064e-04 - mean_absolute_error: 0.0098 - val_loss: 9.3220e-04 - val_mean_absolute_error: 0.0219
# Epoch 72/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.5581e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 73/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.5931e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0013 - val_mean_absolute_error: 0.0278
# Epoch 74/100
# 28/28 [==============================] - 3s 110ms/step - loss: 1.5064e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0020 - val_mean_absolute_error: 0.0355
# Epoch 75/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.5378e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 76/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.4976e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0019 - val_mean_absolute_error: 0.0341
# Epoch 77/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.5102e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 78/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.5254e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 79/100
# 28/28 [==============================] - 2s 72ms/step - loss: 1.5435e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0021 - val_mean_absolute_error: 0.0376
# Epoch 80/100
# 28/28 [==============================] - 3s 112ms/step - loss: 1.5915e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 81/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.3967e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0010 - val_mean_absolute_error: 0.0235
# Epoch 82/100
# 28/28 [==============================] - 2s 72ms/step - loss: 1.4595e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 83/100
# 28/28 [==============================] - 2s 70ms/step - loss: 1.5342e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 84/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.4575e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 85/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.4358e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0019 - val_mean_absolute_error: 0.0361
# Epoch 86/100
# 28/28 [==============================] - 3s 109ms/step - loss: 1.6428e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0019 - val_mean_absolute_error: 0.0352
# Epoch 87/100
# 28/28 [==============================] - 2s 71ms/step - loss: 1.3956e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 88/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.3371e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 89/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.3610e-04 - mean_absolute_error: 0.0084 - val_loss: 7.2182e-04 - val_mean_absolute_error: 0.0192
# Epoch 90/100
# 28/28 [==============================] - 2s 67ms/step - loss: 1.3500e-04 - mean_absolute_error: 0.0082 - val_loss: 7.1515e-04 - val_mean_absolute_error: 0.0193
# Epoch 91/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.2866e-04 - mean_absolute_error: 0.0081 - val_loss: 8.1409e-04 - val_mean_absolute_error: 0.0206
# Epoch 92/100
# 28/28 [==============================] - 3s 100ms/step - loss: 1.5136e-04 - mean_absolute_error: 0.0090 - val_loss: 6.7768e-04 - val_mean_absolute_error: 0.0182
# Epoch 93/100
# 28/28 [==============================] - 2s 81ms/step - loss: 1.2979e-04 - mean_absolute_error: 0.0082 - val_loss: 9.2310e-04 - val_mean_absolute_error: 0.0231
# Epoch 94/100
# 28/28 [==============================] - 2s 75ms/step - loss: 1.3462e-04 - mean_absolute_error: 0.0084 - val_loss: 9.1157e-04 - val_mean_absolute_error: 0.0218
# Epoch 95/100
# 28/28 [==============================] - 2s 74ms/step - loss: 1.2655e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 96/100
# 28/28 [==============================] - 2s 68ms/step - loss: 1.2750e-04 - mean_absolute_error: 0.0082 - val_loss: 9.2937e-04 - val_mean_absolute_error: 0.0225
# Epoch 97/100
# 28/28 [==============================] - 2s 73ms/step - loss: 1.3104e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0011 - val_mean_absolute_error: 0.0228
# Epoch 98/100
# 28/28 [==============================] - 3s 104ms/step - loss: 1.3446e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 99/100
# 28/28 [==============================] - 2s 88ms/step - loss: 1.2242e-04 - mean_absolute_error: 0.0079 - val_loss: 6.0156e-04 - val_mean_absolute_error: 0.0176
# Epoch 100/100
# 28/28 [==============================] - 3s 100ms/step - loss: 1.2003e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0015 - val_mean_absolute_error: 0.0285

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 3s 18ms/step
# array([[0.39883795, 0.403526  ],
#        [0.3990068 , 0.4035794 ],
#        [0.3946595 , 0.39923054],
#        [0.39630145, 0.40112466],
#        [0.39877892, 0.40376127]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1410.4136, 1416.131 ],
#        [1410.7267, 1416.2299],
#        [1402.6671, 1408.1699],
#        [1405.7112, 1411.6804],
#        [1410.3042, 1416.5669]], dtype=float32)

# %% [markdown]
# ACTUAL VS PREDICTED DATA VISULAIZATION

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1410.413574      1416.130981
# 2020-05-28  1396.86  1416.73     1410.726685      1416.229858
# 2020-05-29  1416.94  1428.92     1402.667114      1408.169922
# 2020-06-01  1418.39  1431.82     1405.711182      1411.680420
# 2020-06-02  1430.55  1439.22     1410.304199      1416.566895

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# 10 DAYS PREDICTION

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2297.560547      2458.624512
# 2021-06-10  2494.01  2521.60     2308.859619      2472.588623
# 2021-06-11  2524.92  2513.93     2316.383301      2483.102051
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Opening price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming closing price prediction',size=15)
ax.legend()
fig.show()
